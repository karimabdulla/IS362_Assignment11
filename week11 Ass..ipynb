# %%
import pandas as pd
import urllib.request
import json
from pandas.io.json import json_normalize

# %%
api_key = 'UO8UQKUOhL08v5wzYhkkrx3vn5jhsG4t'
url = 'https://api.nytimes.com/svc/topstories/v2/home.json?'
string = url+'&api-key='+api_key
w_data = str(urllib.request.urlopen(string).read(), 'utf-8')

# Lets convert w_data to dataframe

t_story = json.loads(w_data)
t_story
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.',
#  'section': 'home',
#  'last_updated': '2023-11-05T08:19:08-05:00',
#  'num_results': 22,
#  'results': [{'section': 'us',
#    'subsection': 'politics',
#    'title': 'Trump Leads in 5 Critical States as Voters Blast Biden, Times/Siena Poll Finds',
#    'abstract': 'Voters in battleground states said they trusted Donald J. Trump over President Biden on the economy, foreign policy and immigration, as Mr. Biden’s multiracial base shows signs of fraying.',
#    'url': 'https://www.nytimes.com/2023/11/05/us/politics/biden-trump-2024-poll.html',
#    'uri': 'nyt://article/dee2339e-7274-5b60-b04d-dde415e0b644',
#    'byline': 'By Shane Goldmacher',
#    'item_type': 'Article',
#    'updated_date': '2023-11-05T05:01:35-05:00',
#    'created_date': '2023-11-05T05:01:35-05:00',
#    'published_date': '2023-11-05T05:01:35-05:00',
#    'material_type_facet': '',
#    'kicker': '',
# ...

# %%
#Sorting data can be done as needed since data is formated in dataframe below
story = json_normalize (t_story['results'])
story.head(10)
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_25888\2061884206.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   story = json_normalize (t_story['results'])
#     section  subsection                                              title  \
# 0        us    politics  Trump Leads in 5 Critical States as Voters Bla...
# 1    upshot                Why Biden Is Behind, and How He Could Come Back
# 2     world        asia  Half a World Away, Thais Pray for Loved Ones C...
# 3     world  middleeast  Journalists get a glimpse inside Israel’s inva...
# 4        us    politics  U.S. Officials Outline Steps to Israel to Redu...
# 5        us              A Secret War, Strange New Wounds and Silence F...
# 6        us              Five Takeaways From a Times Investigation of A...
# 7    movies              With ‘Dream Scenario,’ Nicolas Cage Reclaims t...
# 8        us    politics  ‘Like Winning the Lottery’: Mike Johnson’s Asc...
# ...
